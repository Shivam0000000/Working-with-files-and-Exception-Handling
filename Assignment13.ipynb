# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %%
"""Exception class as the base class for custom exceptions ensures 
   compatibility and standardization with Python's exception handling mechanism."""

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)


print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
#             SSLError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
"""ZeroDivisionError: This error occurs when attempting to divide a number by zero."""
#For example:
numerator = 10
denominator = 0

try:
    result = numerator / denominator
except ZeroDivisionError as e:
    print("Error: Division by zero!")
    
"""OverflowError:This error occurs when the result of an arithmetic operation 
   exceeds the maximum representable value for a numeric type."""
#For example:    
large_number = 10 ** 10000

try:
    result = large_number * large_number

except OverflowError as e:
    print("Error: Numeric overflow!")

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
"""LookupError class is used to handle lookup-related errors. 
   KeyError is raised when a dictionary key is not found, 
   while IndexError is raised when accessing a list with an invalid index."""

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
"""ImportError is raised when a module cannot be imported. 
   ModuleNotFoundError is a subclass of ImportError specifically 
   raised when a module is not found."""

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
"""
(1)use alwalys a specific exception
(2)print always a proper message
(3)always try to log your code
(4)always avoid to write multiple exception handling
(5)document all the error
(6)cleanup all the resources
"""
